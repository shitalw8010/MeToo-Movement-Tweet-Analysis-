# %%
import pandas as pd
import numpy as np
import matplotlib .pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('../ADMIN/Downloads/MeTooHate.csv')

# %%
df
# Out:
#                   status_id  \
# 0       1046207313588236290
# 1       1046207328113086464
# 2       1046207329589493760
# 3       1046207341283168256
# 4       1046207347016826880
# ...                     ...
# 807169  1097646408608505856
# 807170  1097646574686126081
# 807171  1097646591882809350
# 807172  1097646692877381632
# 807173  1097646743204835328
#
#                                                      text  \
# 0       Entitled, obnoxious, defensive, lying weasel. ...
# 1       Thank you  and  for what you did for the women...
# 2       Knitting (s) &amp; getting ready for January 1...
# 3       Yep just like triffeling women weaponized thei...
# 4       No, the President wants to end  movement posin...
# ...                                                   ...
# 807169  Let’s not forget that this “iconic kiss” was u...
# 807170  DEFINITELY....the only one any of us should su...
# 807171  Did the  movement count the dollars of Erin An...
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 807174 entries, 0 to 807173
# Data columns (total 10 columns):
#  #   Column           Non-Null Count   Dtype
# ---  ------           --------------   -----
#  0   status_id        807174 non-null  int64
#  1   text             803638 non-null  object
#  2   created_at       807174 non-null  object
#  3   favorite_count   807174 non-null  int64
#  4   retweet_count    807174 non-null  int64
#  5   location         616406 non-null  object
#  6   followers_count  807174 non-null  int64
#  7   friends_count    807174 non-null  int64
#  8   statuses_count   807174 non-null  int64
#  9   category         807174 non-null  int64
# dtypes: int64(7), object(3)
# memory usage: 61.6+ MB

# %%
df.isnull().sum()
# Out:
# status_id               0
# text                 3536
# created_at              0
# favorite_count          0
# retweet_count           0
# location           190768
# followers_count         0
# friends_count           0
# statuses_count          0
# category                0
# dtype: int64

# %%
df.shape
# Out:
# (807174, 10)

# %%
df.head()
# Out:
#              status_id                                               text  \
# 0  1046207313588236290  Entitled, obnoxious, defensive, lying weasel. ...
# 1  1046207328113086464  Thank you  and  for what you did for the women...
# 2  1046207329589493760  Knitting (s) &amp; getting ready for January 1...
# 3  1046207341283168256  Yep just like triffeling women weaponized thei...
# 4  1046207347016826880  No, the President wants to end  movement posin...
#
#              created_at  favorite_count  retweet_count         location  \
# 0  2018-09-30T01:17:15Z               5              1      McAllen, TX
# 1  2018-09-30T01:17:19Z               5              2        Tampa, FL
# 2  2018-09-30T01:17:19Z               0              0     St Cloud, MN
# 3  2018-09-30T01:17:22Z               1              0  flyover country
# 4  2018-09-30T01:17:23Z               0              0            World
#
#    followers_count  friends_count  statuses_count  category
# ...

# %%
df.tail()
# Out:
#                   status_id  \
# 807169  1097646408608505856
# 807170  1097646574686126081
# 807171  1097646591882809350
# 807172  1097646692877381632
# 807173  1097646743204835328
#
#                                                      text  \
# 807169  Let’s not forget that this “iconic kiss” was u...
# 807170  DEFINITELY....the only one any of us should su...
# 807171  Did the  movement count the dollars of Erin An...
# 807172  This is one of my all time fav songs &amp; vid...
# 807173   I watched your news on the death of the sailo...
#
#                   created_at  favorite_count  retweet_count  \
# 807169  2019-02-18T23:57:51Z               2              0
# 807170  2019-02-18T23:58:31Z               3              0
# 807171  2019-02-18T23:58:35Z               0              0
# 807172  2019-02-18T23:58:59Z               1              1
# 807173  2019-02-18T23:59:11Z               1              0
#
# ...

# %%
df['text']
# Out:
# 0         Entitled, obnoxious, defensive, lying weasel. ...
# 1         Thank you  and  for what you did for the women...
# 2         Knitting (s) &amp; getting ready for January 1...
# 3         Yep just like triffeling women weaponized thei...
# 4         No, the President wants to end  movement posin...
#                                 ...
# 807169    Let’s not forget that this “iconic kiss” was u...
# 807170    DEFINITELY....the only one any of us should su...
# 807171    Did the  movement count the dollars of Erin An...
# 807172    This is one of my all time fav songs &amp; vid...
# 807173     I watched your news on the death of the sailo...
# Name: text, Length: 807174, dtype: object

# %%
def checking_null_values (df):
    na_columns = [col for col in df.columns if df[col].isna().sum()>0]
    na_miss = df[na_columns].isna().sum().sort_values(ascending = False)
    ratio = (df [na_columns].isna().sum()/df.shape[0]*100).sort_values(ascending = False)
    missing_df = pd.concat([na_miss , np.round(ratio ,2)],axis = 1 , keys = ['Null values' , 'Percentage'])
    missing_df = pd.DataFrame(missing_df)
    return missing_df.style.background_gradient(cmap = 'winter_r')
checking_null_values(df)
# Out:
# <style type="text/css">
# #T_b555c_row0_col0, #T_b555c_row0_col1 {
#   background-color: #0000ff;
#   color: #f1f1f1;
# }
# #T_b555c_row1_col0, #T_b555c_row1_col1 {
#   background-color: #00ff80;
#   color: #000000;
# }
# </style>
# <table id="T_b555c">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_b555c_level0_col0" class="col_heading level0 col0" >Null values</th>
#       <th id="T_b555c_level0_col1" class="col_heading level0 col1" >Percentage</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_b555c_level0_row0" class="row_heading level0 row0" >location</th>
#       <td id="T_b555c_row0_col0" class="data row0 col0" >190768</td>
#       <td id="T_b555c_row0_col1" class="data row0 col1" >23.630000</td>
#     </tr>
#     <tr>
#       <th id="T_b555c_level0_row1" class="row_heading level0 row1" >text</th>
#       <td id="T_b555c_row1_col0" class="data row1 col0" >3536</td>
# ...

# %%
# see the numerical columns in the data 
num_col = [col for col in df.columns if df[col].dtype!='object']
num_col
# Out:
# ['status_id',
#  'favorite_count',
#  'retweet_count',
#  'followers_count',
#  'friends_count',
#  'statuses_count',
#  'category']

# %%
cat_col = [col for col in df.columns if df[col].dtype !='object']
cat_col
# Out:
# ['status_id',
#  'favorite_count',
#  'retweet_count',
#  'followers_count',
#  'friends_count',
#  'statuses_count',
#  'category']

# %%
df['category'].value_counts()
# Out:
# 0    711840
# 1     95334
# Name: category, dtype: int64

# %%
df['category'].value_counts()[0]
# Out:
# 711840

# %%
df['category'].value_counts()[0], df['category'].value_counts()[1]
# Out:
# (711840, 95334)

# %% [markdown]
# # Explore Data Analysis Process

# %%
import matplotlib.pyplot as plt
import numpy as np

y = np.array(df['category'].value_counts().sort_values(ascending = False))
mylabels = ['Non - Hatred' , 'hatred']
explode = [0.2,0.05]
autopct = ['%1.2f%%']
title = 'percentage of the harm and not - harm twittes'


plt.pie(y, labels = mylabels )
plt.show()

# %%
df['location'].value_counts()[:50]\
.sort_values(ascending = False)\
.plot(kind = 'bar' , title = "which location most twitted " ,color = ['red','gray'])
plt.xlabel("Location") 
plt.ylabel('count')
plt.show()

# %%
df.groupby(['status_id'])['followers_count'].sum()[:50]\
.sort_values(ascending = False)\
.plot(kind = 'bar' ,figsize = (17,5),title = 'to visualize the followers of the each member', color = ['red' , 'blue'])
plt.xlabel('status_id')
plt.ylabel('count of values')
plt.show()

# %%
# to visualised the follwers count in the data 
df['followers_count'].value_counts ().sort_values(ascending = False)[:50]\
.plot(kind = 'bar', title = 'to visualize follwers count' , color = ['black','red'] , figsize = (17,5))
plt.xlabel('followers_count')
plt.ylabel('count of followers')
plt.show()

# %%
# Visualize the text length in the text data
df['text']= df['text'].astype(str)
df['text_length'] = df['text'].apply(len)
df['text_length'].value_counts()[:100]\
.plot(kind = 'bar' , title ='visualize the chartest is length in tha data',color = ['green','blue'] , figsize = (18,8))
plt.xlabel('length of the text')
plt.ylabel('Count of the value')
plt.show()

# %% [markdown]
# # Observations
# 1 from the above data 53 char text most used in the data and then 64 char lenght text used

# %%
df['created_at' ]=pd.to_datetime (df['created_at'])

df['year']=df['created_at'].dt.year

df['month']=df['created_at'].dt.month

labels=['2018', '2019'],

df['year'].value_counts().plot(kind='pie', explode=[0.2,0.05], colors=['red', 'gray'], shadow=True, title="Percentage of the twitter in the year wise", figsize=(16,5))

autopct='%1.2f%%',

plt.show()

# %% [markdown]
# # observations
# most of the twitters in 2018 with 83% percentage and 16% tiwtted in 2019 year

# %%
follwer_max = df['followers_count'].max()
follwer_min = df['followers_count'].min()
friend_max = df['friends_count'].max()
friend_min = df['friends_count'].min()

print(f'the highest followers in the data is {follwer_max}')
print(f'the highest followers in the data is {follwer_min}') 
print(f'the highest friends in the data is {friend_max}')
print(f'the highest friends in the data is {friend_min}')
# Out:
# the highest followers in the data is 54576429
# the highest followers in the data is 0
# the highest friends in the data is 899383
# the highest friends in the data is 0

# %%
df ['created_at'] = pd.to_datetime(df['created_at'])
df['year'] = df['created_at'].df.year
#df['date'] = df['created_at'].df.year
df['month'] = df['created_at'].df.month
df['year'].value_counts().plot(kind = 'pie', explode = [0.2,0.05],
        labels = ['2018','2019'],colors = ['red','gray'],autopct = '%1.2%%',
                              shadow = True , title = 'Percentage of the Twitter in the year wise' ,figsize = (16,5))
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[22], line 2
#       1 df ['created_at'] = pd.to_datetime(df['created_at'])
# ----> 2 df['year'] = df['created_at'].df.year
#       3 #df['date'] = df['created_at'].df.year
#       4 df['month'] = df['created_at'].df.month
#
# File ~\anaconda3\lib\site-packages\pandas\core\generic.py:5902, in NDFrame.__getattr__(self, name)
#    5895 if (
#    5896     name not in self._internal_names_set
#    5897     and name not in self._metadata
#    5898     and name not in self._accessors
#    5899     and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    5900 ):
#    5901     return self[name]
# -> 5902 return object.__getattribute__(self, name)
#
# AttributeError: 'Series' object has no attribute 'df'

# %%
follwer_max = df['followers_count'].max()
follwer_min = df['followers_count'].min()
friend_max = df['friends_count'].max()
friens_min = df['friends_count'].min()

# %% [markdown]
# # data Cleaning Procees

# %%
import string 
string.punctuation
# Out:
# '!"#$%&\'()*+,-./:;<=>?@[\\]^_`{|}~'

# %%
# remove punctuation from the data we take the sample question
harm = df[df['category']==1]
q1 = harm['text'].values[0]
q1
# Out:
# 'Yep just like triffeling women weaponized their poon!! Wonder if Kamala Harris ever extorted Willy Brown after throwing the poon on him, oh yeh, that how she got her first job me too is a JOKE! '

# %%
# remove the extra keyword in the data with sample question
test_punc_remove = [char for char in q1 if char not in string. punctuation]
test_punc_removed =''.join(test_punc_remove)
test_punc_removed
# Out:
# 'Yep just like triffeling women weaponized their poon Wonder if Kamala Harris ever extorted Willy Brown after throwing the poon on him oh yeh that how she got her first job me too is a JOKE '

# %%
# another method for removing the string punctuations
test_punc_remove = []
for char in q1:
    if char not in string.punctuation:
        test_punc_remove.append(char)
punc_remove = ''.join(test_punc_remove)
punc_remove
# Out:
# 'Yep just like triffeling women weaponized their poon Wonder if Kamala Harris ever extorted Willy Brown after throwing the poon on him oh yeh that how she got her first job me too is a JOKE '

# %%
# create function the most used words in the data 
def punction_remove(text):
    if isinstance(text , float):
        return text
    else:
        test_punc_remove = [char for char in text if char not in string. punctuation]
        test_punc_removed = ''.join(test_punc_remove)
        return test_punc_removed
df['text'] = df['text'].apply(punction_remove)

# %%
pip install wordcloud wikipedia pillow
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from wordcloud import WordCloud,STOPWORDS

# %%
wordcloud = WordCloud(width = 800, height = 800,
                background_color ='white',
                stopwords = stopwords,
                min_font_size = 10).generate(comment_words)
plt.figure(figsize = (8, 8), facecolor = None)
plt.imshow(wordcloud)
plt.axis("off")
plt.tight_layout(pad = 0)
 
plt.show()

# %%
text = '  '.join(str(i) for i in df['text'])
word_cloud = WordCloud(collocations= False , background_color='black' ,width =2000 , height = 1000 , min_font_size = 10 ).generate(text)
plt.figure(figsize = (8,8) , facecolor = None)
plt.imshow(word_cloud)
plt.axis ('off')
plt.show()

# %%
import nltk 

nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\ADMIN\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping corpora\stopwords.zip.
# True

# %%
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer
from nltk.stem.snowball import SnowballStemmer
from nltk.stem import WordNetLemmatizer
from sklearn.feature_extraction.text  import CountVectorizer
from sklearn.model_selection import train_test_split
stopwords = ','.join(stopwords.words('english'))
stopwords
# Out:
# "i,me,my,myself,we,our,ours,ourselves,you,you're,you've,you'll,you'd,your,yours,yourself,yourselves,he,him,his,himself,she,she's,her,hers,herself,it,it's,its,itself,they,them,their,theirs,themselves,what,which,who,whom,this,that,that'll,these,those,am,is,are,was,were,be,been,being,have,has,had,having,do,does,did,doing,a,an,the,and,but,if,or,because,as,until,while,of,at,by,for,with,about,against,between,into,through,during,before,after,above,below,to,from,up,down,in,out,on,off,over,under,again,further,then,once,here,there,when,where,why,how,all,any,both,each,few,more,most,other,some,such,no,nor,not,only,own,same,so,than,too,very,s,t,can,will,just,don,don't,should,should've,now,d,ll,m,o,re,ve,y,ain,aren,aren't,couldn,couldn't,didn,didn't,doesn,doesn't,hadn,hadn't,hasn,hasn't,haven,haven't,isn,isn't,ma,mightn,mightn't,mustn,mustn't,needn,needn't,shan,shan't,shouldn,shouldn't,wasn,wasn't,weren,weren't,won,won't,wouldn,wouldn't"

# %%
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\ADMIN\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping tokenizers\punkt.zip.
# True

# %%
tokenize = word_tokenize(punc_remove)
tokenize
# Out:
# ['Yep',
#  'just',
#  'like',
#  'triffeling',
#  'women',
#  'weaponized',
#  'their',
#  'poon',
#  'Wonder',
#  'if',
#  'Kamala',
#  'Harris',
#  'ever',
#  'extorted',
#  'Willy',
#  'Brown',
#  'after',
#  'throwing',
#  'the',
#  'poon',
#  'on',
#  'him',
#  'oh',
#  'yeh',
#  'that',
#  'how',
#  'she',
#  'got',
#  'her',
#  'first',
#  'job',
#  'me',
#  'too',
#  'is',
#  'a',
#  'JOKE']

# %%
# Remove the stopwords from if the tokenization word we create a function we convert the words  into lower then into if the words
def stopwords_english(text):
    return [word for word in text  if word .lower() not in stopwords]
stopwords_remove = stopwords_english(tokenize)
stopwords_remove
# Out:
# ['Yep',
#  'like',
#  'triffeling',
#  'women',
#  'weaponized',
#  'poon',
#  'Wonder',
#  'Kamala',
#  'Harris',
#  'ever',
#  'extorted',
#  'Willy',
#  'Brown',
#  'throwing',
#  'poon',
#  'oh',
#  'yeh',
#  'got',
#  'first',
#  'job',
#  'JOKE']

# %%
# stemming procees for with stopwords removed data 
stemmer = SnowballStemmer(language = 'english')
stemming_process = [stemmer.stem(word) for word in stopwords_remove]
stemming_process
# Out:
# ['yep',
#  'like',
#  'triffel',
#  'women',
#  'weapon',
#  'poon',
#  'wonder',
#  'kamala',
#  'harri',
#  'ever',
#  'extort',
#  'willi',
#  'brown',
#  'throw',
#  'poon',
#  'oh',
#  'yeh',
#  'got',
#  'first',
#  'job',
#  'joke']

# %%
nltk.download('wordnet')
nltk.download('omw-1.4')
# Out:
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\ADMIN\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package omw-1.4 to
# [nltk_data]     C:\Users\ADMIN\AppData\Roaming\nltk_data...
# True

# %%
# Create a function for the stemming process and lemmatization
def stemming (text):
    stemming = [stemmer.stem(word) for word in stopwords_remove]
    stemming = ' '.join(stemming)
    return stemming 
lemmatizer =  WordNetLemmatizer()
q1_len = lemmatizer.lemmatize(q1)
q1_len
# Out:
# 'Yep just like triffeling women weaponized their poon!! Wonder if Kamala Harris ever extorted Willy Brown after throwing the poon on him, oh yeh, that how she got her first job me too is a JOKE! '

# %%
df .shape
# Out:
# (807174, 11)

# %%
# take the 1lakh samples data
sample_df = df.sample(100000)

# %%
'create a function'
def text_preprocessing (text):
    if isinstance (text , str):
        words = word_tokenize(text)
        words = [word for word in words if word not in stopwords]
        words = [stemmer.stem (word) for word in words]
        words = [lemmatizer.lemmatize(word) for word in words]
        words = [word.lower() for word in words]
        words = ' '.join(words)
        return words
    else:
        return text
sample_df['text']= sample_df['text'].apply(text_preprocessing)

# %%
sample_df.dropna(axis = 0 , inplace = True)

# %%
sample_df.head()
# Out:
#                   status_id  \
# 726875  1085515582299144197
# 352175  1052718404627521536
# 545201  1065013950230814720
# 597568  1070543365857456128
# 418278  1055224667223412736
#
#                                                      text  \
# 726875  i realli think good point im look forward tack...
# 352175                                          read take
# 545201                                   retweet if u cri
# 597568         we are not prey dec 8 2018 trumpet galleri
# 418278  movement inspir man to confess to wit a rape 5...
#
#                       created_at  favorite_count  retweet_count  \
# 726875 2019-01-16 12:34:17+00:00               0              0
# 352175 2018-10-18 00:30:00+00:00               0              0
# 545201 2018-11-20 22:48:07+00:00               0              0
# 597568 2018-12-06 05:00:02+00:00               0              0
# 418278 2018-10-24 22:29:00+00:00               5              3
#
# ...

# %%
X = sample_df['text'].values
y = sample_df['category'].values

# %% [markdown]
# # Machine Learning Modeling Procees

# %%
from sklearn.feature_extraction.text import CountVectorizer,TfidfVectorizer
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score , classification_report,confusion_matrix 
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn .neighbors import KNeighborsClassifier
from sklearn .naive_bayes import MultinomialNB
from sklearn.naive_bayes import BernoulliNB

# %%
vector=TfidfVectorizer()
vector.fit(X)
X = vector.transform(X)
X
# Out:
# <76340x39533 sparse matrix of type '<class 'numpy.float64'>'
# 	with 891190 stored elements in Compressed Sparse Row format>

# %%
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.25,random_state=125)
print(X_train.shape)
print(X_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (57255, 39533)
# (19085, 39533)
# (57255,)
# (19085,)

# %%
def model_building(model,X_train,X_test,y_train,y_test):
    model.fit(X_train,y_train)
    y_pred=model.predict(X_test)
    print(f'the {model} accuracy_score is {accuracy_score(y_test,y_pred)*100:.2f}')
    print(f'the classification_repore of {model} is {classification_report(y_test,y_pred)}')
    matrix=confusion_matrix(y_test,y_pred)
    print(matrix)
    sns.heatmap(matrix,annot=True,cmap='gist_rainbow',xticklabels=['non-hatred','hatred'])
logistic=LogisticRegression()
model_building(logistic,X_train,X_test,y_train,y_test)
# Out:
# the LogisticRegression() accuracy_score is 93.16
# the classification_repore of LogisticRegression() is               precision    recall  f1-score   support
#
#            0       0.93      0.99      0.96     16863
#            1       0.91      0.46      0.61      2222
#
#     accuracy                           0.93     19085
#    macro avg       0.92      0.73      0.79     19085
# weighted avg       0.93      0.93      0.92     19085
#
# [[16757   106]
#  [ 1200  1022]]

# %%
decision=DecisionTreeClassifier()
model_building(decision,X_train,X_test,y_train,y_test)
# Out:
# the DecisionTreeClassifier() accuracy_score is 92.51
# the classification_repore of DecisionTreeClassifier() is               precision    recall  f1-score   support
#
#            0       0.95      0.96      0.96     16863
#            1       0.69      0.64      0.67      2222
#
#     accuracy                           0.93     19085
#    macro avg       0.82      0.80      0.81     19085
# weighted avg       0.92      0.93      0.92     19085
#
# [[16223   640]
#  [  789  1433]]

# %%
knn=KNeighborsClassifier()
model_building(knn,X_train,X_test,y_train,y_test)
# Out:
# the KNeighborsClassifier() accuracy_score is 89.07
# the classification_repore of KNeighborsClassifier() is               precision    recall  f1-score   support
#
#            0       0.89      1.00      0.94     16863
#            1       0.85      0.07      0.14      2222
#
#     accuracy                           0.89     19085
#    macro avg       0.87      0.54      0.54     19085
# weighted avg       0.89      0.89      0.85     19085
#
# [[16834    29]
#  [ 2057   165]]

# %%
multi=MultinomialNB()
model_building(multi,X_train,X_test,y_train,y_test)
# Out:
# the MultinomialNB() accuracy_score is 88.59
# the classification_repore of MultinomialNB() is               precision    recall  f1-score   support
#
#            0       0.89      1.00      0.94     16863
#            1       0.86      0.02      0.05      2222
#
#     accuracy                           0.89     19085
#    macro avg       0.87      0.51      0.49     19085
# weighted avg       0.88      0.89      0.84     19085
#
# [[16854     9]
#  [ 2168    54]]

# %%
bern=BernoulliNB()
model_building(bern,X_train,X_test,y_train,y_test)
# Out:
# the BernoulliNB() accuracy_score is 88.56
# the classification_repore of BernoulliNB() is               precision    recall  f1-score   support
#
#            0       0.92      0.96      0.94     16863
#            1       0.51      0.35      0.41      2222
#
#     accuracy                           0.89     19085
#    macro avg       0.72      0.65      0.68     19085
# weighted avg       0.87      0.89      0.88     19085
#
# [[16127   736]
#  [ 1448   774]]

# %%
from XGBoost import XGBClassifier
xgb=XGBClassifier()
model_building(xgb,X_train,X_test,y_train,y_test)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 from XGBoost import XGBClassifier
#       2 xgb=XGBClassifier()
#       3 model_building(xgb,X_train,X_test,y_train,y_test)
#
# ModuleNotFoundError: No module named 'XGBoost'

# %%
import xgboost as xgb

xgb_cl = xgb.XGBClassifier()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 import xgboost as xgb
#       3 xgb_cl = xgb.XGBClassifier()
#
# ModuleNotFoundError: No module named 'xgboost'
